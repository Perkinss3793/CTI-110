# %% [markdown]
# <a href="https://colab.research.google.com/github/Perkinss3793/CTI-110/blob/main/P1HW2_PerkinsSkyy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Skyy Perkins
# 9/13/2026
# P1HW2
#This program calculates and displays travel expenses

# Get your budget amount
budget_amount = input("Enter your budget amount: ")

# Get your travel destination
travel_destination = input("Enter your travel destination: ")

# Get your gas expense
gas_expense = input("Enter the estimated amount of money that you will spend for gas: ")

#Get your accomodation expense
accomodation_expense = input("Enter the approximate amount that you will need for accomodation/hotel: ")

#Get your food expense
food_expense = input("Enter the amount that you will spend for food: ")


#Display Travel Destination
print(f"Location: {travel_destination}")

#Display Initial Budget
print(f"Initial Budget: {budget_amount}")

#Display Fuel Expense
print(f"Gas Expense: {gas_expense}")

#Display Accomodation Expense
print(f"Accomodation Expense: {accomodation_expense}")

#Display Food Expense
print(f"Food Expense: {food_expense}")

#Calculate the sum
gas2 = int(input("Enter the gas expense amount: "))
accomodation3 = int(input("Enter the accomodation expense amount: "))
food4 = int(input("Enter the food expense amount: "))
print("The sum of expenses are:", gas2 + accomodation3 + food4)

#Calculate the subtraction
num1 = int(input("Enter the initial budget amount: "))
gas2 = int(input("Enter the gas expense amount: "))
accomodation3 = int(input("Enter the accomodation expense amount: "))
food4 = int(input("Enter the food expense amount: "))
print("The subtraction of expenses are:", num1 - gas2 - accomodation3 - food4)

#Display Remaining Balance
print(input("The remaining balance: "))



# Get four numbers from the user
num1 = budget_amount("Enter the initial budget amount: ")
gas2 = gas_expense("Enter the gas expense amount: ")
accomodation3 = accomodation_expense("Enter the accomodation expense amount: ")
food4 = food_expense("Enter the food expense amount: ")

# Display the sum
print(f"The sum of {gas2} and {accomodation3} and {food4} is {total}")
# Out:
# Enter your budget amount: 100
# Enter your travel destination: belize
# Enter the estimated amount of money that you will spend for gas: 10
# Enter the approximate amount that you will need for accomodation/hotel: 10
# Enter the amount that you will spend for food: 10
# Location: belize
# Initial Budget: 100
# Gas Expense: 10
# Accomodation Expense: 10
# Food Expense: 10
# Enter the gas expense amount: 10
# Enter the accomodation expense amount: 10
# Enter the food expense amount: 10
# The sum of expenses are: 30
# Enter the initial budget amount: 100
# Enter the gas expense amount: 10
# Enter the accomodation expense amount: 10
# Enter the food expense amount: 10
# The subtraction of expenses are: 70
